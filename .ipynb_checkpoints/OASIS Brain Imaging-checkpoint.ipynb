# %% [markdown]
# # OASIS 2 Longitudinal MRIs of Brains
#
# Experimenting with reading in .nifti medical images and saving as .jpg to create a future dataset.

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (16,10)

# %%
import nibabel as nib

# %%
img = nib.load('F:/OAS2_RAW_PART1/OAS2_0009_MR1/RAW/mpr-2.nifti.img')

data = img.get_data()
# Out:
# <ipython-input-123-dd92a3581943>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   data = img.get_data()

# %%
img.shape
# Out:
# (256, 256, 128, 1)

# %%
data.shape
# Out:
# (256, 256, 128, 1)

# %%
data[data.shape[0]//2].shape
# Out:
# (256, 128, 1)

# %%
plt.imshow(np.reshape(data[data.shape[0]//2], (256, 128)))

# %%
curr_img = np.reshape(data[data.shape[0]//2], (256, 128))
plt.imshow(curr_img, cmap='gray')

# %%
colour = np.reshape(data[data.shape[0]//2], (256, 128))

# %%
colour.tolist()
# Out:
# [[143.0,
#   108.0,
#   108.0,
#   110.0,
#   60.0,
#   120.0,
#   119.0,
#   187.0,
#   133.0,
#   85.0,
#   65.0,
#   133.0,
#   213.0,
#   83.0,
#   155.0,
#   41.0,
#   116.0,
#   145.0,
#   179.0,
#   246.0,
#   372.0,
#   135.0,
#   60.0,
#   276.0,
#   231.0,
#   223.0,
#   264.0,
#   329.0,
#   302.0,
#   261.0,
#   341.0,
#   353.0,
#   298.0,
#   325.0,
#   333.0,
#   286.0,
#   189.0,
#   366.0,
#   258.0,
#   275.0,
#   308.0,
#   353.0,
#   442.0,
#   432.0,
#   316.0,
#   593.0,
#   205.0,
#   400.0,
#   310.0,
#   287.0,
#   343.0,
#   166.0,
#   131.0,
#   370.0,
#   328.0,
#   278.0,
#   296.0,
#   257.0,
#   243.0,
#   457.0,
#   310.0,
#   485.0,
#   327.0,
#   463.0,
#   427.0,
#   480.0,
#   479.0,
#   496.0,
#   211.0,
#   321.0,
#   267.0,
#   385.0,
#   213.0,
#   272.0,
#   363.0,
#   317.0,
#   143.0,
#   198.0,
#   144.0,
#   290.0,
#   276.0,
#   442.0,
#   206.0,
#   338.0,
#   383.0,
#   515.0,
#   317.0,
#   246.0,
#   337.0,
#   446.0,
#   399.0,
# ...

# %%
np.reshape(colour.tolist(), (256, 128)) ###
# Out:
# array([[143., 108., 108., ..., 171., 209.,  95.],
#        [240., 198., 102., ...,  40., 188., 147.],
#        [190.,  79., 192., ...,  64., 108., 193.],
#        ...,
#        [145.,  43., 242., ..., 118.,  64., 141.],
#        [ 88., 150., 133., ..., 130., 235.,  64.],
#        [163., 100., 164., ..., 128.,  86., 194.]])

# %%
np.array(colour.tolist())
# Out:
# array([[143., 108., 108., ..., 171., 209.,  95.],
#        [240., 198., 102., ...,  40., 188., 147.],
#        [190.,  79., 192., ...,  64., 108., 193.],
#        ...,
#        [145.,  43., 242., ..., 118.,  64., 141.],
#        [ 88., 150., 133., ..., 130., 235.,  64.],
#        [163., 100., 164., ..., 128.,  86., 194.]])

# %%
colour
# Out:
# memmap([[143., 108., 108., ..., 171., 209.,  95.],
#         [240., 198., 102., ...,  40., 188., 147.],
#         [190.,  79., 192., ...,  64., 108., 193.],
#         ...,
#         [145.,  43., 242., ..., 118.,  64., 141.],
#         [ 88., 150., 133., ..., 130., 235.,  64.],
#         [163., 100., 164., ..., 128.,  86., 194.]], dtype=float32)

# %%
import imageio


imageio.imwrite('img_saved.jpg', np.reshape(colour.tolist(), (256, 128)))
img_read = imageio.imread('img_saved.jpg')
# Out:
# Lossy conversion from float64 to uint8. Range [7.0, 3667.0]. Convert image to uint8 prior to saving to suppress this warning.

# %%
plt.imshow(img_read)
